# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import csv

from sklearn import linear_model
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import statsmodels.api as sm

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')
np.random.seed(42)

# %% [markdown]
# #### Set Up Model

# %%
ames_df = pd.read_csv('../data/ames_iowa_data_clean', index_col='Id')

# %%
ames_df_objects = ames_df.select_dtypes(exclude=['int64', 'float64'])

# %%
ames_df_numeric = ames_df.select_dtypes(exclude='object')

# %%
ames_df_objects.head()
# Out:
#     ms_zoning street lot_shape land_contour utilities lot_config land_slope  \
# Id
# 109        RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 544        RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 153        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 318        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 255        RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
#
#     neighborhood condition_1 condition_2    ...    heating heating_qc  \
# Id                                          ...
# 109       Sawyer        RRAe        Norm    ...       GasA         Ex
# 544      SawyerW        Norm        Norm    ...       GasA         Ex
# 153        NAmes        Norm        Norm    ...       GasA         TA
# 318       Timber        Norm        Norm    ...       GasA         Gd
# 255      SawyerW        Norm        Norm    ...       GasA         TA
#
#     central_air electrical kitchen_qual functional garage_type garage_qual  \
# Id
# 109           Y      SBrkr           Gd        Typ      Attchd          TA
# 544           Y      SBrkr           Gd        Typ      Attchd          TA
# 153           Y      SBrkr           Gd        Typ      Detchd          TA
# 318           Y      SBrkr           TA        Typ     BuiltIn          TA
# 255           Y      SBrkr           TA        Typ      Detchd          TA
#
#     paved_drive sale_type
# Id
# 109           Y       WD
# 544           Y       WD
# 153           Y       WD
# 318           Y       WD
# 255           N       WD
#
# [5 rows x 33 columns]

# %%
pd.get_dummies(ames_df_objects, drop_first=True).shape
# Out:
# (2025, 182)

# %%
ames_df_object_dummies = pd.get_dummies(ames_df_objects, drop_first=True)

# %%
ames_df_object_dummies.head()
# Out:
#      ms_zoning_C (all)  ms_zoning_FV  ms_zoning_I (all)  ms_zoning_RH  \
# Id
# 109                  0             0                  0             0
# 544                  0             0                  0             0
# 153                  0             0                  0             0
# 318                  0             0                  0             0
# 255                  0             0                  0             0
#
#      ms_zoning_RL  ms_zoning_RM  street_Pave  lot_shape_IR2  lot_shape_IR3  \
# Id
# 109             1             0            1              0              0
# 544             1             0            1              0              0
# 153             1             0            1              0              0
# 318             1             0            1              0              0
# 255             1             0            1              0              0
#
#      lot_shape_Reg      ...        paved_drive_P  paved_drive_Y  \
# Id                      ...
# 109              0      ...                    0              1
# 544              0      ...                    0              1
# 153              1      ...                    0              1
# 318              1      ...                    0              1
# 255              0      ...                    0              0
#
#      sale_type_CWD  sale_type_Con  sale_type_ConLD  sale_type_ConLI  \
# Id
# 109              0              0                0                0
# 544              0              0                0                0
# 153              0              0                0                0
# 318              0              0                0                0
# 255              0              0                0                0
#
#      sale_type_ConLw  sale_type_New  sale_type_Oth  sale_type_WD
# Id
# 109                0              0              0              1
# 544                0              0              0              1
# 153                0              0              0              1
# 318                0              0              0              1
# 255                0              0              0              1
#
# [5 rows x 182 columns]

# %%
ames_features = pd.concat([ames_df_numeric, ames_df_object_dummies], axis=1)

# %%
ames_features.head()
# Out:
#      ms_subclass  lot_frontage  lot_area  overall_qual  overall_cond  \
# Id
# 109           60       69.0552     13517             6             8
# 544           60       43.0000     11492             7             5
# 153           20       68.0000      7922             5             7
# 318           60       73.0000      9802             5             5
# 255           50       82.0000     14235             6             8
#
#      year_built  year_remod/add  mas_vnr_area  bsmtfin_sf_1  bsmtfin_sf_2  \
# Id
# 109        1976            2005         289.0         533.0           0.0
# 544        1996            1997         132.0         637.0           0.0
# 153        1953            2007           0.0         731.0           0.0
# 318        2006            2007           0.0           0.0           0.0
# 255        1900            1993           0.0           0.0           0.0
#
#          ...        paved_drive_P  paved_drive_Y  sale_type_CWD  \
# Id       ...
# 109      ...                    0              1              0
# 544      ...                    0              1              0
# 153      ...                    0              1              0
# 318      ...                    0              1              0
# 255      ...                    0              0              0
#
#      sale_type_Con  sale_type_ConLD  sale_type_ConLI  sale_type_ConLw  \
# Id
# 109              0                0                0                0
# 544              0                0                0                0
# 153              0                0                0                0
# 318              0                0                0                0
# 255              0                0                0                0
#
#      sale_type_New  sale_type_Oth  sale_type_WD
# Id
# 109              0              0              1
# 544              0              0              1
# 153              0              0              1
# 318              0              0              1
# 255              0              0              1
#
# [5 rows x 214 columns]

# %% [markdown]
# #### Setup X and y

# %%
X = ames_features.drop('saleprice', axis=1)
y = ames_features.saleprice

# %% [markdown]
# #### Create training and validation sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# #### Scale the data

# %%
ss = StandardScaler()

# %%
X_train_sc = ss.fit_transform(X_train)

# %%
X_test_sc = ss.transform(X_test)

# %% [markdown]
# #### CSV and Pickles

# %%
with open('../pickle/X_train_sc.csv', 'w+') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerows(X_train_sc)

# %%
with open('../pickle/X_test_sc.csv', 'w+') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerows(X_test_sc)

# %%
X_train.to_csv('../data/X_train.csv', index=False, header=False)

# %%
X_test.to_csv('../data/X_test.csv', index=False, header=False)

# %%
y_train.to_csv('../data/y_train.csv', index=False, header=False)

# %%
y_test.to_csv('../data/y_test.csv', index=False, header=False)

# %%
with open('../pickle/scaler.pkl', 'wb+') as f:
    pickle.dump(ss, f)
